# %% [markdown]
# В файле 3_1.txt содержится информация о 100 объектах, каждый из объектов характеризуется двумя параметрами - целыми числами, которые получены с двух датчиков.. Известно, что среди данных 100 объектов некоторые из них принадлежат к одной группе. Все остальные не принадлежат ни к какой группе и помещены в набор данных случайным образом. Известно, что в приведённых данных группа объектов характеризуется следующим: объекты принадлежат группе если на расстоянии 15 имеется не менее 10 объектов, принадлежащих данной группе. Определите какие объекты из представленных принадлежат описанной группе и визуализируйте данные объекты.
